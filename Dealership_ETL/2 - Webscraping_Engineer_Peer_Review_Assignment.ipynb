# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Webscraping

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# *   Use webscraping to get bank information

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
#!pip install pandas
# !pip install bs4
#!pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\hi\anaconda3\envs\all\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hi\anaconda3\envs\all\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hi\anaconda3\envs\all\lib\site-packages (from beautifulsoup4->bs4) (2.5)

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## Extract Data Using Web Scraping

# %% [markdown]
# The wikipedia webpage [https://en.wikipedia.org/wiki/List_of_largest_banks](https://en.wikipedia.org/wiki/List_of_largest_banks?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2021-01-01) provides information about largest banks in the world by various parameters. Scrape the data from the table 'By market capitalization' and store it in a JSON file.

# %% [markdown]
# ### Webpage Contents
#
# Gather the contents of the webpage in text format using the `requests` library and assign it to the variable <code>html_data</code>

# %%
#Write your code here
response = requests.get("https://en.wikipedia.org/wiki/List_of_largest_banks")
html_data = response.content

# %% [markdown]
# <b>Question 1</b> Print out the output of the following line, and remember it as it will be a quiz question:

# %%
html_data[101:124]
# Out:
# b'guage-in-main-page-head'

# %% [markdown]
# ### Scraping the Data
#
# <b> Question 2</b> Using the contents and `beautiful soup` load the data from the `By market capitalization` table into a `pandas` dataframe. The dataframe should have the country `Name` and `Market Cap (US$ Billion)` as column names.  Display the first five rows using head.

# %% [markdown]
# Using BeautifulSoup parse the contents of the webpage.

# %%
#Replace the dots below
soup = BeautifulSoup(html_data, "html5lib")

# %% [markdown]
# Load the data from the `By market capitalization` table into a pandas dataframe. The dataframe should have the country `Name` and `Market Cap (US$ Billion)` as column names. Using the empty dataframe `data` and the given loop extract the necessary data from each row and append it to the empty dataframe.

# %%
data = pd.DataFrame(columns=["Name", "Market Cap (US$ Billion)"])
new_data = []
for tbody in soup.find_all('tbody'):
    for row in tbody.find_all('tr'):
        col = row.find_all('td')
        if col:
            marketcap = col[-1].text.strip()
            name = col[1].text.strip()
            new_data.append({"Name": name, "Market Cap (US$ Billion)": marketcap})

data = pd.DataFrame(new_data)

# %% [markdown]
# **Question 3** Display the first five rows using the `head` function.

# %%
#Write your code here
data.head()
# Out:
#                                       Name Market Cap (US$ Billion)
# 0  Industrial and Commercial Bank of China                 6,303.44
# 1               Agricultural Bank of China                 5,623.12
# 2                  China Construction Bank                 5,400.28
# 3                            Bank of China                 4,578.28
# 4                           JPMorgan Chase                 3,875.39

# %% [markdown]
# ### Loading the Data
#
# Usually you will Load the `pandas` dataframe created above into a JSON named `bank_market_cap.json` using the `to_json()` function, but this time the data will be sent to another team who will split the data file into two files and inspect it. If you save the data it will interfere with the next part of the assignment.

# %%
#Write your code here
data = pd.DataFrame(columns=["Name", "Market Cap (US$ Billion)"])
new_data = []
for tbody in soup.find_all('tbody'):
    for row in tbody.find_all('tr'):
        col = row.find_all('td')
        if col:
            marketcap = col[-1].text.strip()
            name = col[1].text.strip()
            new_data.append({"Name": name, "Market Cap (US$ Billion)": marketcap})

data = pd.DataFrame(new_data)
print(data)
# Out:
#                                         Name Market Cap (US$ Billion)
# 0    Industrial and Commercial Bank of China                 6,303.44
# 1                 Agricultural Bank of China                 5,623.12
# 2                    China Construction Bank                 5,400.28
# 3                              Bank of China                 4,578.28
# 4                             JPMorgan Chase                 3,875.39
# ..                                       ...                      ...
# 129                            Bank of China                   171.35
# 130                  China Construction Bank                   166.19
# 131                                     HSBC                   161.05
# 132                           Morgan Stanley                   155.58
# 133                                HDFC Bank                   153.01
#
# [134 rows x 2 columns]

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation.
